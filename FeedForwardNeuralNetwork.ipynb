# %% [markdown]
# <a href="https://colab.research.google.com/github/vamshig04/Data-Science/blob/main/FeedForwardNeuralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
# Load dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print("Training samples:", x_train.shape)
print("Testing samples:", x_test.shape)
# Normalize pixel values
x_train = x_train / 255.0
x_test = x_test / 255.0

# Convert labels to one-hot encoding
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
#Step 4: Build the Feedforward Neural Network
model = Sequential()

# Flatten input layer
model.add(Flatten(input_shape=(28,28)))

# Hidden layers
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))

# Output layer (10 classes)
model.add(Dense(10, activation='softmax'))
#Step 5: Compile the Model
model.compile(

    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
#Step 6: Train the Model
model.fit(
    x_train,
    y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.2
)
#Step 7: Evaluate the Model
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print("Test Accuracy:", test_accuracy)
#Step 8: Make Predictions
predictions = model.predict(x_test)

import numpy as np
print("Predicted digit:", np.argmax(predictions[0]))
print("Actual digit:", np.argmax(y_test[0]))
# Out:
# Training samples: (60000, 28, 28)
# Testing samples: (10000, 28, 28)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9253 - loss: 0.2624 - val_accuracy: 0.9528 - val_loss: 0.1541
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9660 - loss: 0.1102 - val_accuracy: 0.9697 - val_loss: 0.1052
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9760 - loss: 0.0779 - val_accuracy: 0.9667 - val_loss: 0.1063
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9813 - loss: 0.0584 - val_accuracy: 0.9700 - val_loss: 0.1061
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9860 - loss: 0.0448 - val_accuracy: 0.9719 - val_loss: 0.0993
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9875 - loss: 0.0388 - val_accuracy: 0.9712 - val_loss: 0.1081
# Epoch 7/10
# ...
